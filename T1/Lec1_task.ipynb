# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('train.csv')
print(df)
print(df.index)
print(df.columns)
print(df.shape)
print(df.size) #row*column
print(df.values)
print(df.ndim)
print(df.dtypes)
# df.T #transpose
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df['Pclass'])
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
print(pd.DataFrame(df[['Pclass' , 'Age']]))
# Out:
#      Pclass   Age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
print(df[df['Age']>18])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Male  38.0      1
# 2                               Heikkinen, Miss. Laina  Male  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Male  35.0      1
# 4                             Allen, Mr. William Henry  Male  35.0      0
# ..                                                 ...   ...   ...    ...
# ...

# %%
(df['Age']>18) & (df['Sex']=='male')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
print(df[df['Sex']=='female'])
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# ...                                                         ...       ...
# Shelley, Mrs. William (Imanita Parrish Hall)                881         1
# Dahlberg, Miss. Gerda Ulrika                                883         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
#
# ...

# %%
df.iloc[2,2]
# Out:
# 3

# %%
df.iloc[:10 , 3:9]
# Out:
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0      1
# Allen, Mr. William Henry                              male  35.0      0
# Moran, Mr. James                                      male   NaN      0
# McCarthy, Mr. Timothy J                               male  54.0      0
# Palsson, Master. Gosta Leonard                        male   2.0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female  27.0      0
# Nasser, Mrs. Nicholas (Adele Achem)                 female  14.0      1
#
#                                                     Parch            Ticket  \
# Name
# Braund, Mr. Owen Harris                                 0         A/5 21171
# ...

# %%
print(df)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                   22
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.loc['Braund, Mr. Owen Harris':'Nasser, Mrs. Nicholas (Adele Achem)',:'Ticket']
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
#
#                                                     Pclass     Sex   Age  \
# Name
# ...

# %%
df['child'] = df['SibSp']+df['Parch']
print(df)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
# Task
n = np.random.randint(1,100 , [8,5])
print(n)
ds = pd.DataFrame(n , columns=['A','B','C','D','E'])
print(ds)
print(ds.shape)
print(ds.size)
print(ds.ndim)
# Out:
# [[30 75 46 24 41]
#  [66 12 95 73 80]
#  [53 77 85 53 90]
#  [12 60 66 36 18]
#  [80 91 71 28 27]
#  [45  2  6 30 89]
#  [43 38 73 49 48]
#  [45 16 59 24  8]]
#     A   B   C   D   E
# 0  30  75  46  24  41
# 1  66  12  95  73  80
# 2  53  77  85  53  90
# 3  12  60  66  36  18
# 4  80  91  71  28  27
# 5  45   2   6  30  89
# 6  43  38  73  49  48
# 7  45  16  59  24   8
# (8, 5)
# 40
# 2

# %%
ds['Sum'] = ds['A']+ds['B']+ds['C']+ds['D']+ds['E']
print(ds)
# Out:
#     A   B   C   D   E  Sum
# 0  30  75  46  24  41  216
# 1  66  12  95  73  80  326
# 2  53  77  85  53  90  358
# 3  12  60  66  36  18  192
# 4  80  91  71  28  27  297
# 5  45   2   6  30  89  172
# 6  43  38  73  49  48  251
# 7  45  16  59  24   8  152

# %%
ds.iloc[6,2]=56
print(ds)
# Out:
#     A   B   C   D   E  Sum
# 0  30  75  46  24  41  216
# 1  66  12  95  73  80  326
# 2  53  77  85  53  90  358
# 3  12  60  66  36  18  192
# 4  80  91  71  28  27  297
# 5  45   2   6  30  89  172
# 6  43  38  56  49  48  251
# 7  45  16  59  24   8  152

# %%
print(ds.iloc[2:8 , 1:4])
print(ds.loc[2:8 , 'B':'D'])
# Out:
#     B   C   D
# 2  77  85  53
# 3  60  66  36
# 4  91  71  28
# 5   2   6  30
# 6  38  56  49
# 7  16  59  24
#     B   C   D
# 2  77  85  53
# 3  60  66  36
# 4  91  71  28
# 5   2   6  30
# 6  38  56  49
# 7  16  59  24

# %%
ds.loc['new']=[23 , 24 ,25, 26,27,28]
print(ds)
# Out:
#       A   B   C   D   E  Sum
# 0    30  75  46  24  41  216
# 1    66  12  95  73  80  326
# 2    53  77  85  53  90  358
# 3    12  60  66  36  18  192
# 4    80  91  71  28  27  297
# 5    45   2   6  30  89  172
# 6    43  38  56  49  48  251
# 7    45  16  59  24   8  152
# new  23  24  25  26  27   28

# %%
d = np.random.randint(1,100 , [5,4])
df = pd.DataFrame(d , columns=['CourseID','CourseName','Credits','Faculty'])
print(df)
# Out:
#    CourseID  CourseName  Credits  Faculty
# 0        66          55       75       55
# 1        43          88       38       74
# 2        65          90       57       79
# 3        10          75        8       32
# 4        70           4       42       57

# %%
df = df.set_index('CourseID')
print(df)
# Out:
#           CourseName  Credits  Faculty
# CourseID
# 66                55       75       55
# 43                88       38       74
# 65                90       57       79
# 10                75        8       32
# 70                 4       42       57

# %%
df['Semester'] = 1
print(df)
# Out:
#           CourseName  Credits  Faculty  Semester
# CourseID
# 66                55       75       55         1
# 43                88       38       74         1
# 65                90       57       79         1
# 10                75        8       32         1
# 70                 4       42       57         1

# %%
df.iloc[1,1] = 35
print(df)
# Out:
#           CourseName  Credits  Faculty  Semester
# CourseID
# 66                55       75       55         1
# 43                88       35       74         1
# 65                90       57       79         1
# 10                75        8       32         1
# 70                 4       42       57         1

# %%
df.loc['new']=[1,2,3,4]
print(df)
# Out:
#           CourseName  Credits  Faculty  Semester
# CourseID
# 66                55       75       55         1
# 43                88       35       74         1
# 65                90       57       79         1
# 10                75        8       32         1
# 70                 4       42       57         1
# new                1        2        3         4

# %%
t=pd.read_csv('train.csv')
print(t)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
t.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
t.sample()
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 794          795         0       3  Dantcheff, Mr. Ristiu  male  25.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 794      0  349203  7.8958   NaN        S

# %%
t.sample(4)
# Out:
#      PassengerId  Survived  Pclass  \
# 808          809         0       2
# 547          548         1       2
# 498          499         0       1
# 234          235         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 808                                Meyer, Mr. August    male  39.0      0
# 547                       Padro y Manent, Mr. Julian    male   NaN      0
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 234                Leyson, Mr. Robert William Norman    male  24.0      0
#
#      Parch         Ticket      Fare    Cabin Embarked
# 808      0         248723   13.0000      NaN        S
# 547      0  SC/PARIS 2146   13.8625      NaN        C
# 498      2         113781  151.5500  C22 C26        S
# 234      0     C.A. 29566   10.5000      NaN        S

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
t.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                              Name  \
# count    891.000000  891.000000  891.000000                               891
# unique          NaN         NaN         NaN                               891
# top             NaN         NaN         NaN  Najib, Miss. Adele Kiamie "Jane"
# freq            NaN         NaN         NaN                                 1
# mean     446.000000    0.383838    2.308642                               NaN
# std      257.353842    0.486592    0.836071                               NaN
# min        1.000000    0.000000    1.000000                               NaN
# 25%      223.500000    0.000000    2.000000                               NaN
# 50%      446.000000    0.000000    3.000000                               NaN
# 75%      668.500000    1.000000    3.000000                               NaN
# max      891.000000    1.000000    3.000000                               NaN
#
# ...
